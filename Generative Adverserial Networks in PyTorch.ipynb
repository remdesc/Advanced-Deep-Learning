# %% [markdown]
# # Generative Adverserial Networks in PyTorch
#
# Deep neural networks are used mainly for supervised learning: classification or regression. Generative Adverserial Networks or GANs, however, use neural networks for a very different purpose: Generative modeling
#
# > Generative modeling is an unsupervised learning task in machine learning that involves automatically discovering and learning the regularities or patterns in input data in such a way that the model can be used to generate or output new examples that plausibly could have been drawn from the original dataset. - [Source](https://machinelearningmastery.com/what-are-generative-adversarial-networks-gans/)
#
# While there are many approaches used for generative modeling, a Generative Adverserial Network takes the following approach:
#
# ![GAN Flowchart](https://i.imgur.com/6NMdO9u.png)
#
# There are two neural networks: a *Generator* and a *Discriminator*. The generator generates a "fake" sample given a random vector/matrix, and the discriminator attempts to detect whether a given sample is "real" (picked from the training data) or "fake" (generated by the generator). Training happens in tandem: we train the discriminator for a few epochs, then train the generator for a few epochs, and repeat. This way both the generator and the discriminator get better at doing their jobs. This rather simple approach can lead to some astounding results. The following images ([source](https://machinelearningmastery.com/resources-for-getting-started-with-generative-adversarial-networks/)), for instances, were all generated using GANs:
#
# <img src="https://3qeqpr26caki16dnhd19sv6by6v-wpengine.netdna-ssl.com/wp-content/uploads/2019/04/Example-of-Photorealistic-Human-Faces-Generated-by-a-GAN.png" alt="gans_results" width="480">
#
#
# GANs however, can be notoriously difficult to train, and are <strong>extremely sensitive to hyperparameters, activation functions and regularization</strong>. In this workshop, you'll train a GAN to generate images of handwritten digits similar to those from the MNIST database.
#
# <img src="https://i.imgur.com/CAYnuo1.jpg" width="360" >
#
# Refer to this github for full python script: [github.com/yunjey/pytorch-tutorial](https://github.com/yunjey/pytorch-tutorial). <br>
# <strong>Here's what we're going to do:</strong>
#
# * Define the problem statement
# * Load the data (with transforms and normalization)
#     * Denormalize for visual inspection of samples
# * Define the Discriminator network
#     * Study the activation function: Leaky ReLU
# * Define the Generator network
#     * Explain the output activation function: TanH
#     * Look at some sample outputs
# * Define losses, optimizers and helper functions for training
#     * For discriminator
#     * For generator
# * Train the model
#     * Save intermediate generated images to file
# * Look at some outputs
# * Save the models

# %% [markdown]
# ## Load the Data
#
# We begin by downloading and importing the data as a PyTorch dataset using the `MNIST` helper class from `torchvision.datasets`.

# %%
import torch
import torchvision
from torchvision.transforms import ToTensor, Normalize, Compose
from torchvision.datasets import MNIST

mnist = MNIST(root='data', 
              train=True, 
              download=True,
              transform=Compose([ToTensor(), Normalize(mean=(0.5,), std=(0.5,))]))
# Out:
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz to data/MNIST/raw/train-images-idx3-ubyte.gz
#   0%|          | 0/9912422 [00:00<?, ?it/s]
# Extracting data/MNIST/raw/train-images-idx3-ubyte.gz to data/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz to data/MNIST/raw/train-labels-idx1-ubyte.gz
#   0%|          | 0/28881 [00:00<?, ?it/s]
# Extracting data/MNIST/raw/train-labels-idx1-ubyte.gz to data/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz to data/MNIST/raw/t10k-images-idx3-ubyte.gz
#   0%|          | 0/1648877 [00:00<?, ?it/s]
# Extracting data/MNIST/raw/t10k-images-idx3-ubyte.gz to data/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz to data/MNIST/raw/t10k-labels-idx1-ubyte.gz
#   0%|          | 0/4542 [00:00<?, ?it/s]
# Extracting data/MNIST/raw/t10k-labels-idx1-ubyte.gz to data/MNIST/raw

# %% [markdown]
# Note that we are are transforming the pixel values from the range `[0, 1]` to
# the range `[-1, 1]`. The reason for doing this will become clear when define the generator network. Let's look at a sample tensor from the data.
# Also, note how the images and their corresponding label are extracted from the MNIST object. (image = (image - mean) / std)

# %%
img, label = mnist[0]
print('Label: ', label)
print(img[:,10:15,10:15])
torch.min(img), torch.max(img)
# Out:
# Label:  5
# tensor([[[-0.9922,  0.2078,  0.9843, -0.2941, -1.0000],
#          [-1.0000,  0.0902,  0.9843,  0.4902, -0.9843],
#          [-1.0000, -0.9137,  0.4902,  0.9843, -0.4510],
#          [-1.0000, -1.0000, -0.7255,  0.8902,  0.7647],
#          [-1.0000, -1.0000, -1.0000, -0.3647,  0.8824]]])
# (tensor(-1.), tensor(1.))

# %% [markdown]
# As expected, the pixel values range from -1 to 1. Let's define a helper to denormalize and view the images. This function will also be useful for viewing the generated images.

# %%
def denorm(x):
    out = (x + 1) / 2
    return out.clamp(0, 1)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

img_norm = denorm(img)
plt.imshow(img_norm[0], cmap='gray')
print('Label:', label)
# Out:
# Label: 5

# %% [markdown]
# Finally, let's create a dataloader to load the images in batches.

# %%
from torch.utils.data import DataLoader

batch_size = 100
data_loader = DataLoader(mnist, batch_size, shuffle=True)

# %%
for img_batch, label_batch in data_loader:
    print('first batch')
    print(img_batch.shape)
    plt.imshow(img_batch[0][0], cmap='gray')
    print('label: ',label_batch[0].item()) #if You remove the .item() function you will extract a 1x1 Tensor containing the label value
    break #this will stop the loop at its first iteration, but don't forget to take note of how to iterate over a dataloader.
# Out:
# first batch
# torch.Size([100, 1, 28, 28])
# label:  1

# %% [markdown]
# We'll also create a `device` which can be used to move the data and models to a GPU, if one is available.
# Exécution -> Modifier le type d'éxeécution -> Accélérateur matériel (set to GPU)

# %%
# Device configuration
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
device
# Out:
# device(type='cuda')

# %% [markdown]
# ## Discriminator Network
#
# The discriminator takes an image as input, and tries to classify it as "real" or "generated". In this sense, it's like any other neural network. While we can use a CNN for the discriminator, we'll use a simple feedforward network with 3 linear layers to keep things since. We'll treat each 28x28 image as a vector of size 784.

# %%
image_size = 784 #28x28
hidden_size = 256

# %%
import torch.nn as nn
"""
Discriminator Network:
1st layer: Linear layer having input the image_size and output the hidden_size followed by LeakyReLU activation (set it to 0.2)
2nd layer: Linear layer having input the hidden_size and output the hidden_size followed by LeakyReLU activation (set it to 0.2)
last layer: Linear layer having input the hidden_size and output 1 [Classification] followed by a Sigmoid activation
(6 lines, layer, activation, layer, activation, layer, activation)
"""

D = nn.Sequential(
    nn.Linear(image_size,hidden_size),
          nn.LeakyReLU(0.2),
          nn.Linear(hidden_size,hidden_size),
          nn.LeakyReLU(0.2),
          nn.Linear(hidden_size,1),
          nn.Sigmoid()
    ) 
#Try changing this network to a CNN + a final output linear layer?
D.to(device);

# %% [markdown]
# We use the Leaky ReLU activation for the discriminator.
#
# <img src="https://cdn-images-1.medium.com/max/1600/1*ypsvQH7kvtI2BhzR2eT_Sw.png" width="420">
#
#
# >  Different from the regular ReLU function, Leaky ReLU allows the pass of a small gradient signal for negative values. As a result, it makes the gradients from the discriminator flows stronger into the generator. Instead of passing a gradient (slope) of 0 in the back-prop pass, it passes a small negative gradient.  - [Source](https://sthalles.github.io/advanced_gans/)
#
# Just like any other binary classification model, the output of the discriminator is a single number between 0 and 1, which can be interpreted as the probability of the input image being fake i.e. generated.
#
# Let's move the discriminator model to the chosen device.

# %% [markdown]
# ## Generator Network
#
# The input to the generator is typically a vector or a matrix which is used as a seed for generating an image. Once again, to keep things simple, we'll use a feedfoward neural network with 3 layers, and the output will be a vector of size 784, which can be transformed to a 28x28 px image.

# %%
latent_size = 64 #the number of random values to be generated

# %%
"""
Generator Network:
1st layer: Linear layer with input set to latent_size and output set to hidden_size followed by a ReLU activation
2nd layer: Linear layer with input set to hidden_size and output set to hidden_size followed by a ReLU activation
last layer: Linear layer with input set to hidden_size and output set to image_size followed by a Tanh activation
(6 lines, layer, activation, layer, activation, layer, activation)
"""

G = nn.Sequential(
    nn.Linear(latent_size,hidden_size),
          nn.ReLU(),
          nn.Linear(hidden_size,hidden_size),
          nn.ReLU(),
          nn.Linear(hidden_size,image_size),
          nn.Tanh()
    ) 

#can you change this to a CNN-Transpose network? look it up, it's what you want to use if you're going for larger
    #and more sophisticated pictures

# %% [markdown]
# We use the TanH activation function for the output layer of the generator.
#
# <img src="https://nic.schraudolph.org/teach/NNcourse/figs/tanh.gif" width="420" >
#
# > "The ReLU activation (Nair & Hinton, 2010) is used in the generator with the exception of the output layer which uses the Tanh function. We observed that using a bounded activation allowed the model to learn more quickly to saturate and cover the color space of the training distribution. Within the discriminator we found the leaky rectified activation (Maas et al., 2013) (Xu et al., 2015) to work well, especially for higher resolution modeling." - [Source](https://stackoverflow.com/questions/41489907/generative-adversarial-networks-tanh)
#
#
# Note that since the outputs of the TanH activation lie in the range `[-1,1]`, we have applied the same transformation to the images in the training dataset. Let's generate an output vector using the generator and view it as an image by transforming and denormalizing the output.

# %%
y = G(torch.randn(2, latent_size))
gen_imgs = denorm(y.reshape((-1, 28,28)).detach())

# %%
plt.imshow(gen_imgs[0], cmap='gray');

# %% [markdown]
# As one might expect, the output from the generator is random noise. Let's define a helper function which can save a batch of outputs from the generator to a file.
#
# Let's move the generator to the chosen device.

# %%
G.to(device);

# %% [markdown]
# ## Discriminator Training
#
# Since the discriminator is a binary classification model, we can use the binary cross entropy loss function to quantify how well it is able to differentiate between real and generated images.
#
# <img src="https://image.slidesharecdn.com/chrishokamp-dublinnlp3-160805110319/95/task-based-learning-for-nlp-going-beyond-cross-entropy-chris-hokamp-10-638.jpg?cb=1470395213" width="420" >

# %%
from torch import optim
criterion =  nn.BCELoss()
d_optimizer = optim.Adam(D.parameters(), lr=0.0002)

# %%
def reset_grad():
    d_optimizer.zero_grad()
    g_optimizer.zero_grad()

# %%
def train_discriminator(images):
    # Create the labels which are later used as input for the BCE loss
    real_labels = torch.ones(batch_size, 1).to(device) 
    """Generate a vector with a size of batch_size x 1 full of ones (1) and cast it to device [Hint: use .to(device)] (1 line)""" 
    fake_labels = torch.zeros(batch_size, 1).to(device)
    """Generate a vector with a size of batch_size x 1 full of zeros (0) and cast it to device (1 line)"""
        
    # Loss for real images
    outputs = D(images) 
    "Get discriminator output for images"
    d_loss_real = criterion(outputs, real_labels) 
    "Calculate the loss of the discriminator network for real images, don't forget to use only the real_labels(1 line)"
    real_score = outputs

    # Loss for fake images
    z = torch.randn(batch_size, latent_size).to(device)
    """Generate a random vector of size batch_size x latent_size and cast it to device(1 line)"""
    fake_images = G(z) 
    """Get generator output using the random generated vector """
    outputs = D(fake_images) 
    """Get discriminator output for images """
    d_loss_fake = criterion(outputs, fake_labels)
    "Calculate the loss of the discriminator network for fake images, don't forget to use only the fake_labels(1 line)"
    fake_score = outputs

    # Combine losses
    d_loss = d_loss_real + d_loss_fake
    # Reset gradients
    reset_grad() #this is needed to detatch the gradients from the generator network so that we only update the desciminator network
    # Compute gradients
    d_loss.backward()
    # Adjust the parameters using backprop
    d_optimizer.step()
    
    return d_loss, real_score, fake_score

# %% [markdown]
# Here are the steps involved in training the discriminator.
#
# - We expect the discriminator to output 1 if the image was picked from the real MNIST dataset, and 0 if it was generated.
#
# - We first pass a batch of real images, and compute the loss, setting the target labels to 1.
#
# - Then, we generate a batch of fake images using the generator, pass them into the discriminator, and compute the loss, setting the target labels to 0.
#
# - Finally we add the two losses and use the overall loss to perform gradient descent to adjust the weights of the discriminator.
#
# It's important to note that we don't change the weights of the generator model while training the discriminator (`d_optimizer` only affects the `D.parameters()`)

# %% [markdown]
# ## Generator Training
#
# Since the outputs of the generator are images, it's not obvious how we can train the generator. This is where we employ a rather elegant trick, which is to use the discriminator as a part of the loss function. Here's how it works:
#
# - We generate a batch of images using the generator, pass the into the discriminator.
#
# - We calculate the loss by setting the target labels to 1 i.e. real. We do this because the generator's objective is to "fool" the discriminator.
#
# - We use the loss to perform gradient descent i.e. change the weights of the generator, so it gets better at generating real-like images.
#
# Here's what this looks like in code.

# %%
g_optimizer = torch.optim.Adam(G.parameters(), lr=0.0002)

# %%
def train_generator():
    # Generate fake images and calculate loss
    z = torch.randn(batch_size, latent_size).to(device)
    """Generate a random vector of size batch_size x latent_size and cast it to device"""
    fake_images = G(z)
    """Get generator output using the random generated vector )"""
    labels = torch.ones(batch_size, 1).to(device) 
    g_loss = criterion(D(fake_images), labels) #This is used to calculate the generator loss based on the discriminator's performance

    # Backprop and optimize
    reset_grad()
    g_loss.backward()
    g_optimizer.step()
    return g_loss, fake_images

# %% [markdown]
# ## Training the Model
#
# Let's create a directory where we can save intermediate outputs from the generator to visually inspect the progress of the model

# %%
import os

sample_dir = 'samples'
if not os.path.exists(sample_dir):
    os.makedirs(sample_dir)

# %%
from IPython.display import Image
from torchvision.utils import save_image

# Save some real images
for images, _ in data_loader:
    images = images.reshape(images.size(0), 1, 28, 28)
    save_image(denorm(images), os.path.join(sample_dir, 'real_images.png'), nrow=10)
    break
   
Image(os.path.join(sample_dir, 'real_images.png'))

# %% [markdown]
# We'll also define a helper function to save a batch of generated images to disk at the end of every epoch. We'll use a fixed set of input vectors to the generator to see how the individual generated images evolve over time as we train the model.

# %%
sample_vectors = torch.randn(batch_size, latent_size).to(device)

def save_fake_images(index):
    fake_images = G(sample_vectors)
    fake_images = fake_images.reshape(fake_images.size(0), 1, 28, 28)
    fake_fname = 'fake_images-{0:0=4d}.png'.format(index)
    print('Saving', fake_fname)
    save_image(denorm(fake_images), os.path.join(sample_dir, fake_fname), nrow=10)
    
# Before training
save_fake_images(0)
Image(os.path.join(sample_dir, 'fake_images-0000.png'))
# Out:
# Saving fake_images-0000.png

# %% [markdown]
# We are now ready to train the model. In each epoch, we train the discriminator first, and then the generator. The training might take a while if you're not using a GPU.

# %%
# %%time

num_epochs = 50 #IF you want best results, change this to 300, but the sake of time-saving we'll do only 50 epochs
total_step = len(data_loader)
d_losses, g_losses, real_scores, fake_scores = [], [], [], []

for epoch in range(num_epochs):
    for i, (images, _) in enumerate(data_loader):
        # Load a batch & transform to vectors
        images = images.view(batch_size, -1).to(device)
        """resize the batch of images to a batch of 1-D vectors and cast to device. (Hint: use -1) (1 line)"""
        
        # Train the discriminator and generator
        d_loss, real_score, fake_score = train_discriminator(images)
        """call discriminator training function here(1 line)"""
        g_loss, fake_images = train_generator()
        """call discriminator training function here(1 line)"""
        
        # Inspect the losses
        if (i+1) % 200 == 0:
            d_losses.append(d_loss.item())
            g_losses.append(g_loss.item())
            real_scores.append(real_score.mean().item())
            fake_scores.append(fake_score.mean().item())
            print('Epoch [{}/{}], Step [{}/{}], d_loss: {:.4f}, g_loss: {:.4f}, D(x): {:.2f}, D(G(z)): {:.2f}' 
                  .format(epoch, num_epochs, i+1, total_step, d_loss.item(), g_loss.item(), 
                          real_score.mean().item(), fake_score.mean().item()))
        
    # Sample and save images
    save_fake_images(epoch+1)
# Out:
# Epoch [0/50], Step [200/600], d_loss: 0.0340, g_loss: 13.7219, D(x): 1.00, D(G(z)): 0.03
# Epoch [0/50], Step [400/600], d_loss: 0.0675, g_loss: 6.2283, D(x): 0.99, D(G(z)): 0.06
# Epoch [0/50], Step [600/600], d_loss: 0.2173, g_loss: 6.1102, D(x): 0.95, D(G(z)): 0.03
# Saving fake_images-0001.png
# Epoch [1/50], Step [200/600], d_loss: 0.1071, g_loss: 6.6051, D(x): 0.98, D(G(z)): 0.06
# Epoch [1/50], Step [400/600], d_loss: 0.1303, g_loss: 6.0944, D(x): 0.97, D(G(z)): 0.05
# Epoch [1/50], Step [600/600], d_loss: 0.0828, g_loss: 5.9734, D(x): 0.99, D(G(z)): 0.07
# Saving fake_images-0002.png
# Epoch [2/50], Step [200/600], d_loss: 0.0957, g_loss: 7.0864, D(x): 0.98, D(G(z)): 0.02
# Epoch [2/50], Step [400/600], d_loss: 0.0625, g_loss: 5.5409, D(x): 0.99, D(G(z)): 0.05
# Epoch [2/50], Step [600/600], d_loss: 0.1396, g_loss: 4.6038, D(x): 0.96, D(G(z)): 0.05
# Saving fake_images-0003.png
# Epoch [3/50], Step [200/600], d_loss: 0.0716, g_loss: 5.5059, D(x): 0.99, D(G(z)): 0.04
# Epoch [3/50], Step [400/600], d_loss: 0.1394, g_loss: 5.5887, D(x): 0.97, D(G(z)): 0.05
# Epoch [3/50], Step [600/600], d_loss: 0.0380, g_loss: 4.8200, D(x): 0.99, D(G(z)): 0.03
# Saving fake_images-0004.png
# Epoch [4/50], Step [200/600], d_loss: 0.1181, g_loss: 4.7484, D(x): 0.96, D(G(z)): 0.04
# Epoch [4/50], Step [400/600], d_loss: 0.1044, g_loss: 4.3609, D(x): 0.98, D(G(z)): 0.05
# Epoch [4/50], Step [600/600], d_loss: 0.0151, g_loss: 6.4867, D(x): 1.00, D(G(z)): 0.01
# Saving fake_images-0005.png
# Epoch [5/50], Step [200/600], d_loss: 0.0700, g_loss: 7.2610, D(x): 0.97, D(G(z)): 0.01
# Epoch [5/50], Step [400/600], d_loss: 0.1109, g_loss: 5.9266, D(x): 0.96, D(G(z)): 0.03
# Epoch [5/50], Step [600/600], d_loss: 0.0351, g_loss: 6.2043, D(x): 0.99, D(G(z)): 0.02
# Saving fake_images-0006.png
# Epoch [6/50], Step [200/600], d_loss: 0.0469, g_loss: 5.5710, D(x): 0.99, D(G(z)): 0.04
# Epoch [6/50], Step [400/600], d_loss: 0.0768, g_loss: 4.9380, D(x): 0.99, D(G(z)): 0.05
# Epoch [6/50], Step [600/600], d_loss: 0.1673, g_loss: 6.5260, D(x): 0.95, D(G(z)): 0.04
# Saving fake_images-0007.png
# Epoch [7/50], Step [200/600], d_loss: 0.0562, g_loss: 6.0625, D(x): 0.98, D(G(z)): 0.02
# Epoch [7/50], Step [400/600], d_loss: 0.0611, g_loss: 6.6940, D(x): 0.98, D(G(z)): 0.01
# Epoch [7/50], Step [600/600], d_loss: 0.0814, g_loss: 6.0444, D(x): 0.99, D(G(z)): 0.06
# Saving fake_images-0008.png
# Epoch [8/50], Step [200/600], d_loss: 0.2823, g_loss: 4.8700, D(x): 0.95, D(G(z)): 0.09
# Epoch [8/50], Step [400/600], d_loss: 0.1044, g_loss: 5.3160, D(x): 0.97, D(G(z)): 0.02
# Epoch [8/50], Step [600/600], d_loss: 0.1429, g_loss: 4.0707, D(x): 0.95, D(G(z)): 0.04
# Saving fake_images-0009.png
# Epoch [9/50], Step [200/600], d_loss: 0.1574, g_loss: 5.5239, D(x): 0.97, D(G(z)): 0.03
# Epoch [9/50], Step [400/600], d_loss: 0.2071, g_loss: 5.7475, D(x): 0.98, D(G(z)): 0.12
# Epoch [9/50], Step [600/600], d_loss: 0.0445, g_loss: 7.4544, D(x): 0.98, D(G(z)): 0.01
# Saving fake_images-0010.png
# Epoch [10/50], Step [200/600], d_loss: 0.2368, g_loss: 4.1328, D(x): 0.95, D(G(z)): 0.09
# Epoch [10/50], Step [400/600], d_loss: 0.1189, g_loss: 4.5383, D(x): 0.95, D(G(z)): 0.03
# Epoch [10/50], Step [600/600], d_loss: 0.2444, g_loss: 4.7784, D(x): 0.94, D(G(z)): 0.02
# Saving fake_images-0011.png
# Epoch [11/50], Step [200/600], d_loss: 0.3323, g_loss: 3.4262, D(x): 0.92, D(G(z)): 0.08
# Epoch [11/50], Step [400/600], d_loss: 0.1434, g_loss: 5.2479, D(x): 0.97, D(G(z)): 0.07
# Epoch [11/50], Step [600/600], d_loss: 0.2839, g_loss: 5.0350, D(x): 0.89, D(G(z)): 0.03
# Saving fake_images-0012.png
# Epoch [12/50], Step [200/600], d_loss: 0.2910, g_loss: 3.5895, D(x): 0.90, D(G(z)): 0.04
# Epoch [12/50], Step [400/600], d_loss: 0.3562, g_loss: 3.2907, D(x): 0.89, D(G(z)): 0.05
# Epoch [12/50], Step [600/600], d_loss: 0.2401, g_loss: 5.4715, D(x): 0.90, D(G(z)): 0.03
# Saving fake_images-0013.png
# Epoch [13/50], Step [200/600], d_loss: 0.4633, g_loss: 4.7039, D(x): 0.92, D(G(z)): 0.19
# Epoch [13/50], Step [400/600], d_loss: 0.5215, g_loss: 5.3872, D(x): 0.84, D(G(z)): 0.02
# Epoch [13/50], Step [600/600], d_loss: 0.3122, g_loss: 4.8409, D(x): 0.95, D(G(z)): 0.13
# Saving fake_images-0014.png
# Epoch [14/50], Step [200/600], d_loss: 0.2864, g_loss: 4.0711, D(x): 0.91, D(G(z)): 0.06
# Epoch [14/50], Step [400/600], d_loss: 0.2672, g_loss: 4.5480, D(x): 0.95, D(G(z)): 0.12
# Epoch [14/50], Step [600/600], d_loss: 0.3102, g_loss: 5.3133, D(x): 0.92, D(G(z)): 0.07
# Saving fake_images-0015.png
# Epoch [15/50], Step [200/600], d_loss: 0.3153, g_loss: 5.8611, D(x): 0.96, D(G(z)): 0.17
# Epoch [15/50], Step [400/600], d_loss: 0.3610, g_loss: 4.4383, D(x): 0.92, D(G(z)): 0.11
# Epoch [15/50], Step [600/600], d_loss: 0.2814, g_loss: 4.8740, D(x): 0.89, D(G(z)): 0.03
# Saving fake_images-0016.png
# Epoch [16/50], Step [200/600], d_loss: 0.2738, g_loss: 3.6810, D(x): 0.93, D(G(z)): 0.15
# Epoch [16/50], Step [400/600], d_loss: 0.2708, g_loss: 3.7943, D(x): 0.92, D(G(z)): 0.08
# Epoch [16/50], Step [600/600], d_loss: 0.2142, g_loss: 4.2614, D(x): 0.94, D(G(z)): 0.10
# Saving fake_images-0017.png
# Epoch [17/50], Step [200/600], d_loss: 0.5928, g_loss: 3.2437, D(x): 0.82, D(G(z)): 0.09
# Epoch [17/50], Step [400/600], d_loss: 0.4576, g_loss: 4.1073, D(x): 0.87, D(G(z)): 0.08
# Epoch [17/50], Step [600/600], d_loss: 0.3409, g_loss: 2.9831, D(x): 0.94, D(G(z)): 0.18
# Saving fake_images-0018.png
# Epoch [18/50], Step [200/600], d_loss: 0.3152, g_loss: 4.5921, D(x): 0.89, D(G(z)): 0.10
# Epoch [18/50], Step [400/600], d_loss: 0.7657, g_loss: 2.8427, D(x): 0.84, D(G(z)): 0.14
# Epoch [18/50], Step [600/600], d_loss: 0.5267, g_loss: 3.3723, D(x): 0.82, D(G(z)): 0.04
# Saving fake_images-0019.png
# Epoch [19/50], Step [200/600], d_loss: 0.2446, g_loss: 3.9664, D(x): 0.94, D(G(z)): 0.08
# Epoch [19/50], Step [400/600], d_loss: 0.2633, g_loss: 3.9114, D(x): 0.94, D(G(z)): 0.13
# Epoch [19/50], Step [600/600], d_loss: 0.3822, g_loss: 4.3629, D(x): 0.92, D(G(z)): 0.08
# Saving fake_images-0020.png
# Epoch [20/50], Step [200/600], d_loss: 0.3696, g_loss: 3.6238, D(x): 0.91, D(G(z)): 0.12
# Epoch [20/50], Step [400/600], d_loss: 0.2979, g_loss: 3.6909, D(x): 0.93, D(G(z)): 0.11
# Epoch [20/50], Step [600/600], d_loss: 0.2566, g_loss: 4.5273, D(x): 0.95, D(G(z)): 0.12
# Saving fake_images-0021.png
# Epoch [21/50], Step [200/600], d_loss: 0.2770, g_loss: 4.7670, D(x): 0.89, D(G(z)): 0.07
# Epoch [21/50], Step [400/600], d_loss: 0.3334, g_loss: 4.2548, D(x): 0.90, D(G(z)): 0.10
# Epoch [21/50], Step [600/600], d_loss: 0.5059, g_loss: 3.3870, D(x): 0.89, D(G(z)): 0.15
# Saving fake_images-0022.png
# Epoch [22/50], Step [200/600], d_loss: 0.2263, g_loss: 5.1701, D(x): 0.95, D(G(z)): 0.10
# Epoch [22/50], Step [400/600], d_loss: 0.1943, g_loss: 5.8695, D(x): 0.95, D(G(z)): 0.08
# Epoch [22/50], Step [600/600], d_loss: 0.2064, g_loss: 4.6993, D(x): 0.95, D(G(z)): 0.11
# Saving fake_images-0023.png
# Epoch [23/50], Step [200/600], d_loss: 0.3746, g_loss: 4.9382, D(x): 0.91, D(G(z)): 0.14
# Epoch [23/50], Step [400/600], d_loss: 0.3166, g_loss: 5.0664, D(x): 0.92, D(G(z)): 0.10
# Epoch [23/50], Step [600/600], d_loss: 0.3686, g_loss: 4.2046, D(x): 0.96, D(G(z)): 0.20
# Saving fake_images-0024.png
# Epoch [24/50], Step [200/600], d_loss: 0.2689, g_loss: 5.0844, D(x): 0.90, D(G(z)): 0.07
# Epoch [24/50], Step [400/600], d_loss: 0.2726, g_loss: 3.7571, D(x): 0.89, D(G(z)): 0.05
# Epoch [24/50], Step [600/600], d_loss: 0.3869, g_loss: 3.3410, D(x): 0.91, D(G(z)): 0.10
# Saving fake_images-0025.png
# Epoch [25/50], Step [200/600], d_loss: 0.2368, g_loss: 3.9472, D(x): 0.93, D(G(z)): 0.10
# Epoch [25/50], Step [400/600], d_loss: 0.2168, g_loss: 3.6392, D(x): 0.91, D(G(z)): 0.06
# Epoch [25/50], Step [600/600], d_loss: 0.6691, g_loss: 2.2940, D(x): 0.81, D(G(z)): 0.20
# Saving fake_images-0026.png
# Epoch [26/50], Step [200/600], d_loss: 0.3722, g_loss: 3.8685, D(x): 0.88, D(G(z)): 0.11
# Epoch [26/50], Step [400/600], d_loss: 0.5550, g_loss: 3.7077, D(x): 0.88, D(G(z)): 0.15
# Epoch [26/50], Step [600/600], d_loss: 0.3551, g_loss: 3.1527, D(x): 0.86, D(G(z)): 0.09
# Saving fake_images-0027.png
# Epoch [27/50], Step [200/600], d_loss: 0.5604, g_loss: 3.2065, D(x): 0.87, D(G(z)): 0.16
# Epoch [27/50], Step [400/600], d_loss: 0.3874, g_loss: 4.2239, D(x): 0.87, D(G(z)): 0.13
# Epoch [27/50], Step [600/600], d_loss: 0.2758, g_loss: 4.0141, D(x): 0.93, D(G(z)): 0.13
# Saving fake_images-0028.png
# Epoch [28/50], Step [200/600], d_loss: 0.4040, g_loss: 3.1112, D(x): 0.86, D(G(z)): 0.11
# Epoch [28/50], Step [400/600], d_loss: 0.2657, g_loss: 2.9269, D(x): 0.96, D(G(z)): 0.17
# Epoch [28/50], Step [600/600], d_loss: 0.6860, g_loss: 3.4026, D(x): 0.83, D(G(z)): 0.19
# Saving fake_images-0029.png
# Epoch [29/50], Step [200/600], d_loss: 0.3380, g_loss: 3.9813, D(x): 0.90, D(G(z)): 0.11
# Epoch [29/50], Step [400/600], d_loss: 0.5920, g_loss: 3.7069, D(x): 0.84, D(G(z)): 0.11
# Epoch [29/50], Step [600/600], d_loss: 0.5582, g_loss: 3.0218, D(x): 0.84, D(G(z)): 0.15
# Saving fake_images-0030.png
# Epoch [30/50], Step [200/600], d_loss: 0.5282, g_loss: 3.7268, D(x): 0.87, D(G(z)): 0.21
# Epoch [30/50], Step [400/600], d_loss: 0.3669, g_loss: 4.0512, D(x): 0.86, D(G(z)): 0.07
# Epoch [30/50], Step [600/600], d_loss: 0.4512, g_loss: 3.7142, D(x): 0.83, D(G(z)): 0.12
# Saving fake_images-0031.png
# Epoch [31/50], Step [200/600], d_loss: 0.3485, g_loss: 4.2897, D(x): 0.85, D(G(z)): 0.06
# Epoch [31/50], Step [400/600], d_loss: 0.3171, g_loss: 3.7369, D(x): 0.86, D(G(z)): 0.09
# Epoch [31/50], Step [600/600], d_loss: 0.3613, g_loss: 2.7063, D(x): 0.89, D(G(z)): 0.13
# Saving fake_images-0032.png
# Epoch [32/50], Step [200/600], d_loss: 0.5365, g_loss: 3.4100, D(x): 0.80, D(G(z)): 0.11
# Epoch [32/50], Step [400/600], d_loss: 0.4497, g_loss: 3.6501, D(x): 0.89, D(G(z)): 0.13
# Epoch [32/50], Step [600/600], d_loss: 0.8354, g_loss: 2.8128, D(x): 0.74, D(G(z)): 0.19
# Saving fake_images-0033.png
# Epoch [33/50], Step [200/600], d_loss: 0.9734, g_loss: 3.0997, D(x): 0.67, D(G(z)): 0.11
# Epoch [33/50], Step [400/600], d_loss: 0.4460, g_loss: 2.8738, D(x): 0.85, D(G(z)): 0.16
# Epoch [33/50], Step [600/600], d_loss: 0.5166, g_loss: 2.3120, D(x): 0.84, D(G(z)): 0.15
# Saving fake_images-0034.png
# Epoch [34/50], Step [200/600], d_loss: 0.5603, g_loss: 3.5811, D(x): 0.84, D(G(z)): 0.18
# Epoch [34/50], Step [400/600], d_loss: 0.5117, g_loss: 2.1235, D(x): 0.89, D(G(z)): 0.23
# Epoch [34/50], Step [600/600], d_loss: 0.4804, g_loss: 2.6740, D(x): 0.83, D(G(z)): 0.13
# Saving fake_images-0035.png
# Epoch [35/50], Step [200/600], d_loss: 0.5484, g_loss: 3.4387, D(x): 0.87, D(G(z)): 0.21
# Epoch [35/50], Step [400/600], d_loss: 0.3941, g_loss: 3.1538, D(x): 0.84, D(G(z)): 0.07
# Epoch [35/50], Step [600/600], d_loss: 0.4382, g_loss: 2.8183, D(x): 0.83, D(G(z)): 0.10
# Saving fake_images-0036.png
# Epoch [36/50], Step [200/600], d_loss: 0.6190, g_loss: 3.9955, D(x): 0.79, D(G(z)): 0.08
# Epoch [36/50], Step [400/600], d_loss: 0.8517, g_loss: 3.0593, D(x): 0.70, D(G(z)): 0.12
# Epoch [36/50], Step [600/600], d_loss: 0.5522, g_loss: 2.6156, D(x): 0.80, D(G(z)): 0.12
# Saving fake_images-0037.png
# Epoch [37/50], Step [200/600], d_loss: 0.3547, g_loss: 3.4059, D(x): 0.89, D(G(z)): 0.14
# Epoch [37/50], Step [400/600], d_loss: 0.5561, g_loss: 3.2192, D(x): 0.90, D(G(z)): 0.24
# Epoch [37/50], Step [600/600], d_loss: 0.5434, g_loss: 2.6122, D(x): 0.88, D(G(z)): 0.20
# Saving fake_images-0038.png
# Epoch [38/50], Step [200/600], d_loss: 0.4410, g_loss: 3.7223, D(x): 0.90, D(G(z)): 0.18
# Epoch [38/50], Step [400/600], d_loss: 0.5366, g_loss: 2.4640, D(x): 0.89, D(G(z)): 0.23
# Epoch [38/50], Step [600/600], d_loss: 0.7499, g_loss: 2.2052, D(x): 0.78, D(G(z)): 0.21
# Saving fake_images-0039.png
# Epoch [39/50], Step [200/600], d_loss: 0.4896, g_loss: 3.1713, D(x): 0.90, D(G(z)): 0.23
# Epoch [39/50], Step [400/600], d_loss: 0.5142, g_loss: 3.7481, D(x): 0.80, D(G(z)): 0.07
# Epoch [39/50], Step [600/600], d_loss: 0.6825, g_loss: 3.0206, D(x): 0.76, D(G(z)): 0.12
# Saving fake_images-0040.png
# Epoch [40/50], Step [200/600], d_loss: 0.5852, g_loss: 3.3762, D(x): 0.77, D(G(z)): 0.12
# Epoch [40/50], Step [400/600], d_loss: 0.6835, g_loss: 2.9349, D(x): 0.74, D(G(z)): 0.13
# Epoch [40/50], Step [600/600], d_loss: 0.7421, g_loss: 2.4586, D(x): 0.77, D(G(z)): 0.23
# Saving fake_images-0041.png
# Epoch [41/50], Step [200/600], d_loss: 0.6484, g_loss: 3.0445, D(x): 0.83, D(G(z)): 0.22
# Epoch [41/50], Step [400/600], d_loss: 0.6797, g_loss: 2.3167, D(x): 0.82, D(G(z)): 0.24
# Epoch [41/50], Step [600/600], d_loss: 0.6413, g_loss: 2.9797, D(x): 0.79, D(G(z)): 0.19
# Saving fake_images-0042.png
# Epoch [42/50], Step [200/600], d_loss: 0.5596, g_loss: 2.7717, D(x): 0.81, D(G(z)): 0.18
# Epoch [42/50], Step [400/600], d_loss: 0.8314, g_loss: 2.1704, D(x): 0.77, D(G(z)): 0.24
# Epoch [42/50], Step [600/600], d_loss: 0.5630, g_loss: 3.4690, D(x): 0.84, D(G(z)): 0.19
# Saving fake_images-0043.png
# Epoch [43/50], Step [200/600], d_loss: 0.7673, g_loss: 3.5810, D(x): 0.76, D(G(z)): 0.15
# Epoch [43/50], Step [400/600], d_loss: 0.7285, g_loss: 2.6166, D(x): 0.79, D(G(z)): 0.25
# Epoch [43/50], Step [600/600], d_loss: 0.5746, g_loss: 2.7963, D(x): 0.77, D(G(z)): 0.15
# Saving fake_images-0044.png
# Epoch [44/50], Step [200/600], d_loss: 0.5931, g_loss: 2.5735, D(x): 0.78, D(G(z)): 0.15
# Epoch [44/50], Step [400/600], d_loss: 0.5911, g_loss: 2.4793, D(x): 0.75, D(G(z)): 0.13
# Epoch [44/50], Step [600/600], d_loss: 0.5473, g_loss: 2.6600, D(x): 0.78, D(G(z)): 0.15
# Saving fake_images-0045.png
# Epoch [45/50], Step [200/600], d_loss: 0.6208, g_loss: 2.5181, D(x): 0.79, D(G(z)): 0.18
# Epoch [45/50], Step [400/600], d_loss: 0.5238, g_loss: 2.2880, D(x): 0.81, D(G(z)): 0.17
# Epoch [45/50], Step [600/600], d_loss: 0.7986, g_loss: 2.2911, D(x): 0.78, D(G(z)): 0.22
# Saving fake_images-0046.png
# Epoch [46/50], Step [200/600], d_loss: 0.6286, g_loss: 2.6175, D(x): 0.82, D(G(z)): 0.21
# Epoch [46/50], Step [400/600], d_loss: 0.5452, g_loss: 2.1308, D(x): 0.83, D(G(z)): 0.19
# Epoch [46/50], Step [600/600], d_loss: 0.5325, g_loss: 2.1610, D(x): 0.82, D(G(z)): 0.17
# Saving fake_images-0047.png
# Epoch [47/50], Step [200/600], d_loss: 0.8084, g_loss: 2.0584, D(x): 0.71, D(G(z)): 0.17
# Epoch [47/50], Step [400/600], d_loss: 0.5562, g_loss: 1.9231, D(x): 0.89, D(G(z)): 0.26
# Epoch [47/50], Step [600/600], d_loss: 0.6802, g_loss: 1.7156, D(x): 0.83, D(G(z)): 0.22
# Saving fake_images-0048.png
# Epoch [48/50], Step [200/600], d_loss: 0.6437, g_loss: 3.2938, D(x): 0.76, D(G(z)): 0.14
# Epoch [48/50], Step [400/600], d_loss: 0.5512, g_loss: 2.2927, D(x): 0.87, D(G(z)): 0.24
# Epoch [48/50], Step [600/600], d_loss: 0.6567, g_loss: 2.3098, D(x): 0.83, D(G(z)): 0.21
# Saving fake_images-0049.png
# Epoch [49/50], Step [200/600], d_loss: 0.4200, g_loss: 2.4016, D(x): 0.88, D(G(z)): 0.20
# Epoch [49/50], Step [400/600], d_loss: 0.5712, g_loss: 1.7678, D(x): 0.79, D(G(z)): 0.18
# Epoch [49/50], Step [600/600], d_loss: 0.6029, g_loss: 1.7081, D(x): 0.86, D(G(z)): 0.26
# Saving fake_images-0050.png
# CPU times: user 12min 59s, sys: 5.87 s, total: 13min 5s
# Wall time: 13min 4s

# %%
# Save the model checkpoints 
torch.save(G.state_dict(), 'G.ckpt')
torch.save(D.state_dict(), 'D.ckpt')

# %% [markdown]
# Here's how the generated images look, after the 1st, 10th, 50th and 300th epochs of training.

# %%
Image('./samples/fake_images-0001.png')

# %%
Image('./samples/fake_images-0010.png')

# %%
Image('./samples/fake_images-0050.png')

# %% [markdown]
# ## Result after 100 epochs

# %%
Image('./samples/fake_images-0100.png')

# %% [markdown]
# ## Result after 300 epochs

# %%
Image('./samples/epoch300.png')

# %% [markdown]
# ## Loss observation
# We can visualize how the loss changes over time. Visualizing losses is quite useful for debugging the training process. For GANs, we expect the generator's loss to reduce over time, without the discriminator's loss getting too high.

# %%
plt.plot(d_losses, '-')
plt.plot(g_losses, '-')
plt.xlabel('epoch')
plt.ylabel('loss')
plt.legend(['Discriminator', 'Generator'])
plt.title('Losses');

# %%
plt.plot(real_scores, '-')
plt.plot(fake_scores, '-')
plt.xlabel('epoch')
plt.ylabel('score')
plt.legend(['Real Score', 'Fake score'])
plt.title('Scores');
